# %%
URL = "https://scontent.fblr2-1.fna.fbcdn.net/v/t1.0-1/p160x160/18199317_1342144572536371_7757547685879733298_n.jpg?oh=b0582cb9d4dc18eab72b716dad61a62d&oe=5A61AB42"

# %%
import urllib, cStringIO
from PIL import Image

file = cStringIO.StringIO(urllib.urlopen(URL).read())
img = Image.open(file)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x160 at 0x7F462008D810>
